# %% [markdown]
# <a href="https://colab.research.google.com/github/setran11/ds1002-mnd4up/blob/main/notebooks/25-plots-in-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
library(ggplot2)
install.packages("gapminder")
library(gapminder)

# %%
data()

# %%
quickplot(data = iris, Sepal.Width, Sepal.Length)
# Out:
# plot without title

# %%
quickplot(data = iris, Petal.Length, Petal.Width)
# Out:
# plot without title

# %%
ggplot(iris, aes(x=Petal.Length, fill=Species)) + geom_histogram(binwidth = 0.1)
# Out:
# plot without title

# %%
ggplot(data = BOD,
  mapping = aes(x = Time, y = demand)) +
  geom_point(size = 4, color = "blue") +
  geom_line(color = "red")
# Out:
# plot without title

# %%
install.packages("gridExtra")
library(gridExtra)

common_subplot <- function(data, field) {
  ggplot(data, aes(x=get(field), fill=Species)) +
    geom_density(alpha=0.2) +
    labs(x=field, y="Density")
}

plen <- common_subplot(iris, "Petal.Length")
pwth <- common_subplot(iris, "Petal.Width")
slen <- common_subplot(iris, "Sepal.Length")
swth <- common_subplot(iris, "Sepal.Width")

grid.arrange(plen, pwth, slen, swth, nrow = 2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %%
theme_set(theme_classic())

g <- ggplot(mpg, aes(displ)) + scale_fill_brewer(palette = "Spectral")

g + geom_histogram(aes(fill=class),
    binwidth = .1,
    col = "black",
    linewidth = .1) +
    labs(
      title="Histogram with Auto Binning", subtitle = "Engine Displacement across vehicle classes"
    )

g + geom_histogram(aes(fill=class),
    bins = 5,
    col="black",
    linewidth=.1) +
    labs(
      title="Histogram with Fixed Binning", subtitle = "Engine Displacement across vehicle classes"
    )
# Out:
# plot without title
# plot without title
