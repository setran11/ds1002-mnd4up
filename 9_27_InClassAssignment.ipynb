# %% [markdown]
# <a href="https://colab.research.google.com/github/setran11/ds1002-mnd4up/blob/main/9_27_InClassAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Load the LA crime data into Colab
# 2. Load it into a pandas DF
# 3. First 50 records

# %%
import numpy as np
import pandas as pd

la_crime = pd.read_csv("la-crime-2020-present.csv")

la_crime.head(50)
# Out:
#         DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0    10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1   190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2   200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3   191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4   191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
# 5   200100501  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM        30     1
# 6   200100502  01/02/2020 12:00:00 AM  01/02/2020 12:00:00 AM      1315     1
# 7   200100504  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM        40     1
# 8   200100507  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM       200     1
# 9   201710201  06/19/2020 12:00:00 AM  05/26/2020 12:00:00 AM      1925    17
# 10  200100509  01/04/2020 12:00:00 AM  01/04/2020 12:00:00 AM      2200     1
# ...

# %%
la_crime.loc[:50, ['DATE OCC','Crm Cd Desc']]
# Out:
#                   DATE OCC                                        Crm Cd Desc
# 0   01/08/2020 12:00:00 AM                           BATTERY - SIMPLE ASSAULT
# 1   01/01/2020 12:00:00 AM                           BATTERY - SIMPLE ASSAULT
# 2   02/13/2020 12:00:00 AM          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3   01/01/2020 12:00:00 AM           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4   01/01/2020 12:00:00 AM  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 5   01/01/2020 12:00:00 AM                                     RAPE, FORCIBLE
# 6   01/02/2020 12:00:00 AM           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 7   01/04/2020 12:00:00 AM                          OTHER MISCELLANEOUS CRIME
# 8   01/04/2020 12:00:00 AM  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 9   05/26/2020 12:00:00 AM  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 10  01/04/2020 12:00:00 AM                              BURGLARY FROM VEHICLE
# ...
